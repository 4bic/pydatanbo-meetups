# %%
import pandas as pd 
import os

data = ('Kenya_Open_Data_Initiative_KODI_Primary_Schools.csv')

# %%
df = pd.read_csv(data)

# %%
df.head()
# Out:
#        X     Y    FID          Name_of_Sc          Level_  Status  \
# 0  36.14  0.27  10001      CHEBIREBEI PRI  PRIMARY SCHOOL  PUBLIC
# 1  36.17  0.26  10002         WASEGES PRI  PRIMARY SCHOOL  PUBLIC
# 2  36.18  0.24  10003         KIRIBOT PRI  PRIMARY SCHOOL  PUBLIC
# 3  36.19  0.21  10004     KABUSWO PRI SCH  PRIMARY SCHOOL  PUBLIC
# 4  37.70 -0.88  10005  VONDENI PRI SCHOOL  PRIMARY SCHOOL  PUBLIC
#
#                SchSponsor  Type1     Type2     Type3  ...  OthersF  \
# 0  RELIGIOUS ORGANIZATION  MIXED  DAY ONLY  ORDINARY  ...      0.0
# 1  RELIGIOUS ORGANIZATION  MIXED  DAY ONLY  ORDINARY  ...      0.0
# 2               COMMUNITY  MIXED  DAY ONLY  ORDINARY  ...      0.0
# 3               COMMUNITY  MIXED  DAY ONLY  ORDINARY  ...      0.0
# 4               COMMUNITY  MIXED  DAY ONLY  ORDINARY  ...      0.0
#
#    NoTeaching  NonTeachin     Province  District  Division  Location  \
# 0         0.0         0.0  RIFT VALLEY  KOIBATEK  KISANANA   MOGOTIO
# ...

# %%
df.shape
# Out:
# (31230, 38)

# %%
df.describe()
# Out:
#                   X             Y          FID    PupilTeach    ClassrmRat  \
# count  31230.000000  31230.000000  31230.00000  31229.000000  31229.000000
# mean      36.525398     -0.608358  15615.50000     31.162045     30.516667
# std        1.549535      1.200350   9015.46879     24.833860     21.666361
# min       33.930000     -4.660000      1.00000      0.000000      0.000000
# 25%       35.010000     -1.230000   7808.25000     16.300000     17.300000
# 50%       36.810000     -0.560000  15615.50000     30.400000     29.600000
# 75%       37.660000      0.090000  23422.75000     42.100000     40.800000
# max       41.890000      5.290000  31230.00000    839.000000    839.000000
#
#          ToiletRati    No_Classrm    BoysToilet   GirlsToilet    TeachersTo  \
# count  31229.000000  31229.000000  31229.000000  31229.000000  31229.000000
# mean      34.776230      8.973710      4.563739      5.101444      1.907298
# ...

# %%
df.dtypes
# Out:
# X              float64
# Y              float64
# FID              int64
# Name_of_Sc      object
# Level_          object
# Status          object
# SchSponsor      object
# Type1           object
# Type2           object
# Type3           object
# PupilTeach     float64
# ClassrmRat     float64
# ToiletRati     float64
# No_Classrm     float64
# BoysToilet     float64
# GirlsToilet    float64
# TeachersTo     float64
# TotalToile     float64
# TotalBoys      float64
# TotalGirls     float64
# TotalEnrol     float64
# GO_KTSC_M      float64
# GOK_TSC_F      float64
# authorityM     float64
# authorityF     float64
# PTA_BOG_M      float64
# PTA_BOG_F      float64
# OthersM        float64
# OthersF        float64
# NoTeaching     float64
# NonTeachin     float64
# Province        object
# District        object
# Division        object
# Location        object
# Costituenc      object
# Latitude       float64
# Longitude      float64
# dtype: object

# %%
df.BoysToilet.mean()
# Out:
# 4.563738832495437

# %%
df.columns
# Out:
# Index(['X', 'Y', 'FID', 'Name_of_Sc', 'Level_', 'Status', 'SchSponsor',
#        'Type1', 'Type2', 'Type3', 'PupilTeach', 'ClassrmRat', 'ToiletRati',
#        'No_Classrm', 'BoysToilet', 'GirlsToilet', 'TeachersTo', 'TotalToile',
#        'TotalBoys', 'TotalGirls', 'TotalEnrol', 'GO_KTSC_M', 'GOK_TSC_F',
#        'authorityM', 'authorityF', 'PTA_BOG_M', 'PTA_BOG_F', 'OthersM',
#        'OthersF', 'NoTeaching', 'NonTeachin', 'Province', 'District',
#        'Division', 'Location', 'Costituenc', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
df.GirlsToilet.count()
# Out:
# 31229

# %%
df.District.unique()
# Out:
# array(['KOIBATEK', 'MACHAKOS', 'KEIYO', 'TRANS MARA', 'MAKUENI',
#        'LAIKIPIA', 'NAROK', 'BOMET', 'NAIROBI', 'BARINGO', 'KITUI',
#        'ISIOLO', 'MERU NORTH', 'NANDI SOUTH', 'KIAMBU', 'THIKA', 'NYERI',
#        'KERICHO', 'KWALE', 'KILIFI', 'MALINDI', 'MOMBASA', 'TANA RIVER',
#        'BURETI', 'KAJIADO', 'NAKURU', 'SAMBURU', 'TAITA TAVETA',
#        'KIRINYAGA', 'TRANS NZOIA', 'BUNGOMA', 'NANDI NORTH',
#        'UASIN GISHU', 'MARAKWET', 'WEST POKOT', 'LAMU', 'NYANDARUA',
#        'MARAGUA', 'MURANGA', 'MWINGI', 'TURKANA', 'MIGORI',
#        'BUTERE/MUMIAS', 'KAKAMEGA', 'VIHIGA', 'BUSIA', 'SIAYA', 'LUGARI',
#        'TESO', 'MT ELGON', 'SUBA', 'KISUMU', 'KURIA', 'BONDO', 'GUCHA',
#        'NYAMIRA', 'HOMA BAY', 'RACHUONYO', 'NYANDO', 'CENTRAL KISII',
#        'MANDERA', 'IJARA', 'GARISSA', 'WAJIR', 'MBEERE', nan,
#        'MERU SOUTH', 'MERU CENTRAL', 'EMBU', 'MARSABIT', 'THARAKA',
#        'MOYALE'], dtype=object)

# %%
df.GirlsToilet.value_counts()
# Out:
# 4.0      4334
# 2.0      4291
# 1.0      3595
# 6.0      3117
# 3.0      3086
# 0.0      2564
# 8.0      2283
# 5.0      1893
# 10.0     1200
# 7.0      1067
# 12.0      777
# 9.0       687
# 11.0      362
# 14.0      360
# 16.0      342
# 13.0      232
# 15.0      203
# 18.0      190
# 20.0      148
# 17.0       87
# 22.0       64
# 19.0       53
# 24.0       53
# 21.0       47
# 26.0       34
# 23.0       30
# 28.0       25
# 25.0       23
# 30.0       15
# 31.0        9
# 32.0        8
# 39.0        5
# 27.0        5
# 34.0        5
# 33.0        4
# 40.0        4
# 29.0        3
# 55.0        3
# 45.0        2
# 42.0        2
# 43.0        2
# 64.0        2
# 38.0        2
# 49.0        2
# 36.0        2
# 37.0        2
# 82.0        2
# 60.0        1
# 41.0        1
# 196.0       1
# Name: GirlsToilet, dtype: int64

# %%
def mapSchool(x):
    if x == "PUBLIC":
        return 1
    else:
        return 0

# %%
df['school_mapped_value'] = df.Status.apply(mapSchool)

# %%
df.school_mapped_value.value_counts()
# Out:
# 1    23792
# 0     7438
# Name: school_mapped_value, dtype: int64

# %%
pd.read_csv
# Out:
# <function pandas.io.parsers._make_parser_function.<locals>.parser_f>
